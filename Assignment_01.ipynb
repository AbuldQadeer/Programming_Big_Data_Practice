# %% [markdown]
# # Question 1

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot
df=pd.read_csv('jsrt_metadata.csv')

# %%
count=df['diagnosis'].value_counts()
lbl=df['diagnosis'].value_counts().index.tolist()
count
# Out:
# lung cancer                                       56
# lung cancer(adenocarcinoma)                       23
# tuberculoma                                       14
# granuloma                                          8
# lung cancer(bronchioloalveolar cell carcinoma)     7
# unknown                                            4
# metastasis of colon cancer                         4
# inflammatory mass                                  4
# pulmonary tuberculosis                             3
# lung abscess                                       2
# Cryptococcosis                                     2
# lung cancer(squamous cell carcinoma)               2
# Inflammatory mass                                  2
# pulmonary hematoma                                 2
# susp. inflammatory mass                            2
# hamartoma                                          2
# sclerosing hemangioma                              2
# lung cancer(large cell carcinoma)                  1
# susp. hamartoma                                    1
# metastasis of uterine cancer                       1
# organizing pneumonia                               1
# metastasis of ovarian cancer                       1
# metastatic lung cancer                             1
# lung canceror metastasis                           1
# pneumonia                                          1
# calcified granuloma                                1
# lung cancer(adenosquamous carcinoma)               1
# lung cancer(small cell carcinoma)                  1
# susp.tuberculoma                                   1
# organiging pneumonia                               1
# susp. sclerosing hemangioma                        1
# susp. lung metastasis                              1
# Name: diagnosis, dtype: int64

# %%
#Method 2
plt.pyplot.title("Histogram")
plt.pyplot.xlabel("Diseases")
plt.pyplot.ylabel("Frequency")
count.plot(kind='bar', figsize=(14,6))
# Out:
# <AxesSubplot:title={'center':'Histogram'}, xlabel='Diseases', ylabel='Frequency'>

# %% [markdown]
# # Question 2

# %%
states=df['state'].value_counts()
lbl2=df['state'].unique()
states
# Out:
# malignant     100
# non-nodule     93
# benign         54
# Name: state, dtype: int64

# %%
plt.pyplot.pie(states,labels=lbl2,explode=[0,0.1,0.1],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27c3f1cf760>,
#   <matplotlib.patches.Wedge at 0x27c3f1cfee0>,
#   <matplotlib.patches.Wedge at 0x27c3f1e0640>],
#  [Text(0.32391238769004677, 1.051228217420429, 'malignant'),
#   Text(-1.0004055406820234, -0.6627131763988919, 'benign'),
#   Text(0.9279150349340941, -0.7609032053706036, 'non-nodule')],
#  [Text(0.17667948419457094, 0.5733972095020522, '40.5%'),
#   Text(-0.5835698987311803, -0.3865826862326869, '37.7%'),
#   Text(0.5412837703782216, -0.4438602031328521, '21.9%')])

# %% [markdown]
# # Question 3

# %%
data=df[['gender','diagnosis']].value_counts()
lbl3=df[['gender','diagnosis']].value_counts().index.tolist()
data
# Out:
# gender  diagnosis
# Female  lung cancer                                       32
# Male    lung cancer                                       24
# Female  lung cancer(adenocarcinoma)                       15
# Male    tuberculoma                                        9
#         lung cancer(adenocarcinoma)                        8
#         granuloma                                          6
# Female  tuberculoma                                        5
#         lung cancer(bronchioloalveolar cell carcinoma)     4
#         unknown                                            4
# Male    pulmonary tuberculosis                             3
# Female  metastasis of colon cancer                         3
# Male    lung cancer(bronchioloalveolar cell carcinoma)     3
# Female  inflammatory mass                                  2
#         Inflammatory mass                                  2
# Male    lung cancer(squamous cell carcinoma)               2
# Female  granuloma                                          2
#         hamartoma                                          2
# Male    inflammatory mass                                  2
# Female  Cryptococcosis                                     2
#         sclerosing hemangioma                              2
#         susp. lung metastasis                              1
# Male    lung cancer(large cell carcinoma)                  1
#         susp.tuberculoma                                   1
#         susp. inflammatory mass                            1
#         susp. hamartoma                                    1
# Female  lung canceror metastasis                           1
# Male    pulmonary hematoma                                 1
#         organiging pneumonia                               1
#         metastasis of colon cancer                         1
# Female  metastasis of ovarian cancer                       1
# Male    lung cancer(small cell carcinoma)                  1
# Female  metastasis of uterine cancer                       1
#         susp. sclerosing hemangioma                        1
# Male    lung cancer(adenosquamous carcinoma)               1
# Female  metastatic lung cancer                             1
#         organizing pneumonia                               1
# Male    lung abscess                                       1
# Female  pneumonia                                          1
#         pulmonary hematoma                                 1
# Male    calcified granuloma                                1
# Female  susp. inflammatory mass                            1
#         lung abscess                                       1
# dtype: int64

# %%
plt.pyplot.pie(data,labels=lbl3,radius=5,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x27c40ae27f0>,
#   <matplotlib.patches.Wedge at 0x27c40ae2f70>,
#   <matplotlib.patches.Wedge at 0x27c40af26d0>,
#   <matplotlib.patches.Wedge at 0x27c40af2df0>,
#   <matplotlib.patches.Wedge at 0x27c40afd550>,
#   <matplotlib.patches.Wedge at 0x27c40afdc70>,
#   <matplotlib.patches.Wedge at 0x27c41bcc3d0>,
#   <matplotlib.patches.Wedge at 0x27c41bccaf0>,
#   <matplotlib.patches.Wedge at 0x27c41bdb250>,
#   <matplotlib.patches.Wedge at 0x27c41bdb970>,
#   <matplotlib.patches.Wedge at 0x27c40976340>,
#   <matplotlib.patches.Wedge at 0x27c41be87c0>,
#   <matplotlib.patches.Wedge at 0x27c41be8ee0>,
#   <matplotlib.patches.Wedge at 0x27c41bf5640>,
#   <matplotlib.patches.Wedge at 0x27c41bf5d60>,
#   <matplotlib.patches.Wedge at 0x27c41c034c0>,
#   <matplotlib.patches.Wedge at 0x27c41c03be0>,
#   <matplotlib.patches.Wedge at 0x27c41c0f340>,
#   <matplotlib.patches.Wedge at 0x27c41c0fa60>,
#   <matplotlib.patches.Wedge at 0x27c41c201c0>,
#   <matplotlib.patches.Wedge at 0x27c41c208e0>,
#   <matplotlib.patches.Wedge at 0x27c41c20fd0>,
#   <matplotlib.patches.Wedge at 0x27c41c2d760>,
#   <matplotlib.patches.Wedge at 0x27c41c2de80>,
#   <matplotlib.patches.Wedge at 0x27c41c395e0>,
#   <matplotlib.patches.Wedge at 0x27c41c39d00>,
#   <matplotlib.patches.Wedge at 0x27c41c46460>,
#   <matplotlib.patches.Wedge at 0x27c41c46b80>,
#   <matplotlib.patches.Wedge at 0x27c41c542e0>,
#   <matplotlib.patches.Wedge at 0x27c41c54a00>,
#   <matplotlib.patches.Wedge at 0x27c41c61160>,
#   <matplotlib.patches.Wedge at 0x27c41c61880>,
#   <matplotlib.patches.Wedge at 0x27c41c61fa0>,
#   <matplotlib.patches.Wedge at 0x27c409765b0>,
#   <matplotlib.patches.Wedge at 0x27c41c70be0>,
#   <matplotlib.patches.Wedge at 0x27c41c7d340>,
#   <matplotlib.patches.Wedge at 0x27c41c7da60>,
#   <matplotlib.patches.Wedge at 0x27c41c8b1c0>,
#   <matplotlib.patches.Wedge at 0x27c41c8b8e0>,
#   <matplotlib.patches.Wedge at 0x27c41c8bfd0>,
#   <matplotlib.patches.Wedge at 0x27c41c99760>,
#   <matplotlib.patches.Wedge at 0x27c41c99e80>],
#  [Text(4.36912897179769, 3.3407651859713297, "('Female', 'lung cancer')"),
#   Text(-1.2238650650402487, 5.362103533369533, "('Male', 'lung cancer')"),
#   Text(-4.68658715950758, 2.878524065617425, "('Female', 'lung cancer(adenocarcinoma)')"),
#   Text(-5.489703287327283, 0.33638938316781125, "('Male', 'tuberculoma')"),
#   Text(-5.277211432364239, -1.549528798739853, "('Male', 'lung cancer(adenocarcinoma)')"),
#   Text(-4.626894588754134, -2.973524249868782, "('Male', 'granuloma')"),
#   Text(-3.8492172946450687, -3.9285526875180508, "('Female', 'tuberculoma')"),
#   Text(-3.067287913021357, -4.5652759893168655, "('Female', 'lung cancer(bronchioloalveolar cell carcinoma)')"),
#   Text(-2.2847828403152275, -5.002975851690779, "('Female', 'unknown')"),
#   Text(-1.5495293545890618, -5.277211269152184, "('Male', 'pulmonary tuberculosis')"),
#   Text(-0.8936190661717806, -5.426918551496261, "('Female', 'metastasis of colon cancer')"),
#   Text(-0.22433756078275185, -5.4954228826198666, "('Male', 'lung cancer(bronchioloalveolar cell carcinoma)')"),
#   Text(0.336388788874829, -5.4897033237434, "('Female', 'inflammatory mass')"),
#   Text(0.7827312673205068, -5.444017979687322, "('Female', 'Inflammatory mass')"),
#   Text(1.2238647983334277, -5.362103594243614, "('Male', 'lung cancer(squamous cell carcinoma)')"),
#   Text(1.65685371105208, -5.244505294131463, "('Female', 'granuloma')"),
#   Text(2.078816535705832, -5.092005676634306, "('Female', 'hamartoma')"),
#   Text(2.4869451793207973, -4.905619601544034, "('Male', 'inflammatory mass')"),
#   Text(2.878523613115265, -4.686587437436524, "('Female', 'Cryptococcosis')"),
#   Text(3.250945947223079, -4.4363668072234335, "('Female', 'sclerosing hemangioma')"),
#   Text(3.5161953258719976, -4.229228112825781, "('Female', 'susp. lung metastasis')"),
#   Text(3.685773380516187, -4.082287910899755, "('Male', 'lung cancer(large cell carcinoma)')"),
#   Text(3.849216829125828, -3.9285531436362806, "('Male', 'susp.tuberculoma')"),
#   Text(4.006253636211323, -3.768279687383031, "('Male', 'susp. inflammatory mass')"),
#   Text(4.156622429505591, -3.601734301490192, "('Male', 'susp. hamartoma')"),
#   Text(4.300072934992428, -3.4291941843158438, "('Female', 'lung canceror metastasis')"),
#   Text(4.436366393462913, -3.250946511856641, "('Male', 'pulmonary hematoma')"),
#   Text(4.56527595790653, -3.067287959771729, "('Male', 'organiging pneumonia')"),
#   Text(4.6865870710756345, -2.87852420959538, "('Male', 'metastasis of colon cancer')"),
#   Text(4.800097822594833, -2.6849694399602293, "('Female', 'metastasis of ovarian cancer')"),
#   Text(4.905619285020848, -2.4869458036779863, "('Male', 'lung cancer(small cell carcinoma)')"),
#   Text(5.0029758282936285, -2.2847828915478328, "('Female', 'metastasis of uterine cancer')"),
#   Text(5.092005412055235, -2.0788171837850977, "('Female', 'susp. sclerosing hemangioma')"),
#   Text(5.172559855350022, -1.8693914899831343, "('Male', 'lung cancer(adenosquamous carcinoma)')"),
#   Text(5.2445050832572315, -1.6568543785405705, "('Female', 'metastatic lung cancer')"),
#   Text(5.307721350045448, -1.4415595965036385, "('Female', 'organizing pneumonia')"),
#   Text(5.362103438477556, -1.223865480789113, "('Male', 'lung abscess')"),
#   Text(5.407560834934457, -1.0041343617678662, "('Female', 'pneumonia')"),
#   Text(5.444017880066038, -0.7827319602017521, "('Female', 'pulmonary hematoma')"),
#   Text(5.471413894718707, -0.5600267785374772, "('Male', 'calcified granuloma')"),
#   Text(5.4897032809298505, -0.3363894875706334, "('Female', 'susp. inflammatory mass')"),
#   Text(5.498855597821139, -0.11219230950076896, "('Female', 'lung abscess')")],
#  [Text(2.3831612573441947, 1.8222355559843617, '20.8%'),
#   Text(-0.6675627627492267, 2.9247837454742904, '15.6%'),
#   Text(-2.5563202688223163, 1.5701040357913227, '9.7%'),
#   Text(-2.994383611269427, 0.18348511809153342, '5.8%'),
#   Text(-2.8784789631077667, -0.8451975265853744, '5.2%'),
#   Text(-2.5237606847749827, -1.621922318110245, '3.9%'),
#   Text(-2.099573069806401, -2.1428469204643914, '3.2%'),
#   Text(-1.6730661343752857, -2.4901505396273813, '2.6%'),
#   Text(-1.2462451856264876, -2.728895919104062, '2.6%'),
#   Text(-0.845197829775852, -2.87847887408301, '1.9%'),
#   Text(-0.4874285815482439, -2.960137391725233, '1.9%'),
#   Text(-0.12236594224513739, -2.9975033905199275, '1.9%'),
#   Text(0.1834847939317249, -2.9943836311327634, '1.3%'),
#   Text(0.4269443276293673, -2.969464352556721, '1.3%'),
#   Text(0.6675626172727787, -2.924783778678335, '1.3%'),
#   Text(0.903738387846589, -2.860639251344435, '1.3%'),
#   Text(1.1338999285668174, -2.777457641800531, '1.3%'),
#   Text(1.3565155523567984, -2.6757925099331095, '1.3%'),
#   Text(1.570103788971963, -2.556320420419922, '1.3%'),
#   Text(1.773243243939861, -2.419836440303691, '1.3%'),
#   Text(1.917924723202908, -2.306851697904971, '0.6%'),
#   Text(2.0104218439179204, -2.2267024968544114, '0.6%'),
#   Text(2.099572815886815, -2.1428471692561533, '0.6%'),
#   Text(2.185229256115267, -2.0554252840271077, '0.6%'),
#   Text(2.2672485979121406, -1.9645823462673775, '0.6%'),
#   Text(2.345494328177688, -1.8704695550813693, '0.6%'),
#   Text(2.4198362146161347, -1.7732435519218042, '0.6%'),
#   Text(2.4901505224944707, -1.6730661598754888, '0.6%'),
#   Text(2.55632022058671, -1.5701041143247525, '0.6%'),
#   Text(2.618235175960818, -1.4645287854328521, '0.6%'),
#   Text(2.675792337284099, -1.3565158929152652, '0.6%'),
#   Text(2.7288959063419793, -1.2462452135715452, '0.6%'),
#   Text(2.777457497484673, -1.133900282064599, '0.6%'),
#   Text(2.821396284736376, -1.019668085445346, '0.6%'),
#   Text(2.860639136322126, -0.9037387519312203, '0.6%'),
#   Text(2.895120736388426, -0.78630523445653, '0.6%'),
#   Text(2.924783693715031, -0.6675629895213343, '0.6%'),
#   Text(2.9495786372369763, -0.5477096518733816, '0.6%'),
#   Text(2.969464298217839, -0.426944705564592, '0.6%'),
#   Text(2.9844075789374767, -0.30546915192953306, '0.6%'),
#   Text(2.994383607779919, -0.18348517503852732, '0.6%'),
#   Text(2.9993757806297126, -0.06119580518223762, '0.6%')])
